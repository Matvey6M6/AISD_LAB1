# %%
import matplotlib.pyplot  as plt 
import pandas as pd
import re

# %%
filling= pd.Series({1000:0.000179112, 10000:0.00224107,100000:0.0348699})
plt.plot(filling)
plt.title("Заполнение")
plt.show()

# %%
seeking= pd.Series({1000:8.6552e-08, 10000:1.38587e-07,100000:2.9022e-07})
plt.title("Поиск")
plt.plot(seeking)
plt.show()

# %%
insert= pd.Series({1000:1.96343e-07 , 10000:2.77491e-07,100000:7.97022e-07})
plt.plot(insert)
plt.title("Добавление")
plt.show()

# %%
erase= pd.Series({1000:1.43996e-07 , 10000:1.5536e-07,100000:5.19077e-07})
plt.plot(erase)
plt.title("Удаление")
plt.show()
